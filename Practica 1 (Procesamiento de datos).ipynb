# %% [markdown]
# ## Importar librerias y base de datos

# %%
import pandas as pd 
import numpy as np 
import json

# %%
import seaborn as sn

# %%
base = pd.read_csv("unclean_data1.csv") #llamamos al archivo

# %%
base=pd.read_csv("unclean_data1.csv",encoding='utf8') #el encoding='utf8' se utiliza cuando haya simbolos raros

# %% [markdown]
# ##Visualizar los datos

# %%
base.shape #nos arroja cuantas filas, columnas tenemos
# Out:
# (14, 16)

# %%
base.head(20) #vemos nuestra tabla
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# ## Cambiamos nombre a las columnas

# %%
base1=base.rename(columns={'movie_title':'titulo_pelicula','num_voted_users':'numero_votos_usuarios','duration':'duracion','title_year':'año_pelicula'})
#Renombramos las columnas cmabiando la variable

# %%
base1.head(20) #vemos nuestra tabla con los datos cambiados
# Out:
#                                  titulo_pelicula  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
base1.shape
# Out:
# (14, 16)

# %%
base1.columns
# Out:
# Index(['titulo_pelicula', 'num_critic_for_reviews', 'duracion',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'numero_votos_usuarios',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'año_pelicula',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
base1.año_pelicula.unique() #sacamos los valores que no se repiten en nuestra columna
# Out:
# array([2009, 2007, 2015, 2012, 2010, 2016, 2006, 2008], dtype=int64)

# %%
base1['año_pelicula'].dtype #encontramos el tipo de valores que nuestra columna elegida tiene
# Out:
# dtype('int64')

# %%
año_2009=2009
año_2007=2007
año_2015=2015
año_2012=2012
año_2010=2010
año_2016=2016
año_2006=2006
año_2008=2008

# %%
base1.head(30)
# Out:
#                                  titulo_pelicula  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
base2=base1.drop('num_critic_for_reviews', axis = 1 ) #eliminamos las columnas que no necesitamos

# %%
base3=base2.drop('DIRECTOR_facebook_likes', axis = 1 )

# %%
base4=base3.drop('actor_3_facebook_likes', axis = 1 )

# %%
base5=base4.drop('ACTOR_1_facebook_likes', axis = 1 )

# %%
base6=base5.drop('gross', axis = 1 )

# %%
base7=base6.drop('Cast_Total_facebook_likes', axis = 1 )

# %%
base8=base7.drop('facenumber_in_poster', axis = 1 )

# %%
base9=base8.drop('num_user_for_reviews', axis = 1 )

# %%
base10=base9.drop('budget', axis = 1 )

# %%
base11=base10.drop('ACTOR_2_facebook_likes', axis = 1 )

# %%
base12=base11.drop('imdb_score', axis = 1 )

# %%
base13=base12.drop('title_year.1', axis = 1 )

# %%
base13.head()
# Out:
#                               titulo_pelicula  duracion  \
# 0                                    Avatar?ÿ     178.0
# 1  Pirates of the Caribbean: At World's End?ÿ       NaN
# 2                                   Spectre?ÿ     148.0
# 3                     The Dark Knight Rises?ÿ       NaN
# 4                               John Carter?ÿ     132.0
#
#    numero_votos_usuarios  año_pelicula
# 0               886204.0          2009
# 1               471220.0          2007
# 2               275868.0          2015
# 3              1144337.0          2012
# 4               212204.0          2012

# %%
base13.isnull() #así veremos los datoos faltantes
# Out:
#     titulo_pelicula  duracion  numero_votos_usuarios  año_pelicula
# 0             False     False                  False         False
# 1             False      True                  False         False
# 2             False     False                  False         False
# 3             False      True                  False         False
# 4             False     False                  False         False
# 5             False     False                  False         False
# 6             False      True                  False         False
# 7             False     False                  False         False
# 8             False     False                  False         False
# 9             False     False                  False         False
# 10            False     False                   True         False
# 11            False     False                  False         False
# 12            False     False                  False         False
# ...

# %%
base13.isnull().sum() #nos da cuantos valores nulos tenemos por columna
# Out:
# titulo_pelicula          0
# duracion                 3
# numero_votos_usuarios    1
# año_pelicula             0
# dtype: int64

# %%
base13_0=base13.fillna(0) #aplicamos el comando para sustituir los valores

# %%
base13_drop_column=base13.dropna(axis=1) #eliminamos las columnas que tengan datos nulos

# %%
base13.head()
# Out:
#                               titulo_pelicula  duracion  \
# 0                                    Avatar?ÿ     178.0
# 1  Pirates of the Caribbean: At World's End?ÿ       NaN
# 2                                   Spectre?ÿ     148.0
# 3                     The Dark Knight Rises?ÿ       NaN
# 4                               John Carter?ÿ     132.0
#
#    numero_votos_usuarios  año_pelicula
# 0               886204.0          2009
# 1               471220.0          2007
# 2               275868.0          2015
# 3              1144337.0          2012
# 4               212204.0          2012

# %% [markdown]
# En nuestra tabla podemos observar en la primer columna el titulo de la pelicula, seguida de su duracion, numero de votos y el año de la pelicula

# %% [markdown]
# ## Clasificamos los datos

# %%
base14=base13.dropna(subset=["duracion"],axis=0) #Ordenamos los datos ascendentemente conforme los años de las peliculas
base14.sort_values(by=['año_pelicula'],ascending=[True])
# Out:
#                                  titulo_pelicula  duracion  \
# 11                            Superman Returns?ÿ     169.0
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ     151.0
# 5                                 Spider-Man 3?ÿ     156.0
# 12                           Quantum of Solace?ÿ     106.0
# 0                                       Avatar?ÿ     178.0
# 9       Harry Potter and the Half-Blood Prince?ÿ     153.0
# 4                                  John Carter?ÿ     132.0
# 2                                      Spectre?ÿ     148.0
# 7                      Avengers: Age of Ultron?ÿ     141.0
# 8                      Avengers: Age of Ultron?ÿ     141.0
# 10          Batman v Superman: Dawn of Justice?ÿ     183.0
#
#     numero_votos_usuarios  año_pelicula
# 11               240396.0          2006
# 13               522040.0          2006
# 5                383056.0          2007
# 12               330784.0          2008
# 0                886204.0          2009
# ...

# %% [markdown]
# ##Guardamos archivo con las agrupaciones

# %%
nuevo= "Practica1_completo.csv"
base14.to_csv(nuevo)

# %% [markdown]
# ## Preguntas de interés

# %% [markdown]
# 1.Las agrupacionesnos funcionan para organizar los datos de tal manera que observarlos sea de mejor entendimiento, como por ejemplo, por año en el que fueron publicados.
# En nuestra práctica nos puede ayudar para identificar la pelicula que se estrenó primero con el siguiente comando.

# %%
print("Año de la primer pelicula de la lista:",base13['año_pelicula'].min())
respuesta=base13['titulo_pelicula'].min()
# Out:
# Año de la primer pelicula de la lista: 2006

# %% [markdown]
# 2.base13_0=base13.fillna(0) se utiliza para sustituir por 0 los valores nulos de la serie original así ya tendrán un valor y no tendremos problema con manejarlos

# %% [markdown]
# ## Tarea Extra

# %% [markdown]
# df.dropna(): df.dropna(axis = 0) consiste en elegir las filas o columnas que contengas valores faltantes y eliminarlas.
# axis=0 para eliminar filas
# axis=1 para elliminar columnas

# %% [markdown]
# df.astype: se utiliza para cambiar el tipo de dato de una columna.
